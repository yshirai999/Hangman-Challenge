# %% [markdown]
# # Trexquant Interview Project (The Hangman Game)
#
# * Copyright Trexquant Investment LP. All Rights Reserved.
# * Redistribution of this question without written consent from Trexquant is prohibited

# %% [markdown]
# ## Instruction:
# For this coding test, your mission is to write an algorithm that plays the game of Hangman through our API server.
#
# When a user plays Hangman, the server first selects a secret word at random from a list. The server then returns a row of underscores (space separated)—one for each letter in the secret word—and asks the user to guess a letter. If the user guesses a letter that is in the word, the word is redisplayed with all instances of that letter shown in the correct positions, along with any letters correctly guessed on previous turns. If the letter does not appear in the word, the user is charged with an incorrect guess. The user keeps guessing letters until either (1) the user has correctly guessed all the letters in the word
# or (2) the user has made six incorrect guesses.
#
# You are required to write a "guess" function that takes current word (with underscores) as input and returns a guess letter. You will use the API codes below to play 1,000 Hangman games. You have the opportunity to practice before you want to start recording your game results.
#
# Your algorithm is permitted to use a training set of approximately 250,000 dictionary words. Your algorithm will be tested on an entirely disjoint set of 250,000 dictionary words. Please note that this means the words that you will ultimately be tested on do NOT appear in the dictionary that you are given. You are not permitted to use any dictionary other than the training dictionary we provided. This requirement will be strictly enforced by code review.
#
# You are provided with a basic, working algorithm. This algorithm will match the provided masked string (e.g. a _ _ l e) to all possible words in the dictionary, tabulate the frequency of letters appearing in these possible words, and then guess the letter with the highest frequency of appearence that has not already been guessed. If there are no remaining words that match then it will default back to the character frequency distribution of the entire dictionary.
#
# This benchmark strategy is successful approximately 18% of the time. Your task is to design an algorithm that significantly outperforms this benchmark.

# %%
import json
import requests
import random
import string
import secrets
import time
import re
import collections
from submission_agent import guess_YS
from utils import load_cache  # and anything else you need

try:
    from urllib.parse import parse_qs, urlencode, urlparse
except ImportError:
    from urlparse import parse_qs, urlparse
    from urllib import urlencode

from requests.packages.urllib3.exceptions import InsecureRequestWarning

requests.packages.urllib3.disable_warnings(InsecureRequestWarning)
# Out:
# Loading Random Forest model...
# Model loaded successfully.
# Fallback order loaded successfully
# Loaded cached train and test words for transformer.
# Loaded stratified word sample of size 50000 from stratified_word_sample50000.pkl
# Loaded cached transformer data: 200000 samples.
# Loaded cached transformer data from subpattern agent.
# [✓] Loaded cached evaluation data from transformer_eval_data_from_subpattern.pkl (1000 samples)
# Loaded cached transformer data from subpattern agent for short words.
# Loaded cached evaluation data from transformer_eval_data_from_subpattern_short.pkl (1000 samples)
# Using short word samples with subpattern based pattern and guesses from Transformer train dictionary.
# Loading torch_dataset_from_subpattern_short50000.pkl from cache...
# Loaded torch_dataset_from_subpattern_short50000.pkl from cache.
# Training transformer on subpattern-based patterns.
# Using HangmanTransformerModelV3 with subpattern short-word data.
# Model max sequence length set to: 11
# Transformer model loaded from transformer_model_subpattern_v3_short.pt
# Loaded transformer model from transformer_model_subpattern_v3_short.pt
# Agent mode: Subpattern_Greedy

# %%
class HangmanAPI(object):
    def __init__(self, access_token=None, session=None, timeout=None):
        self.hangman_url = self.determine_hangman_url()
        self.access_token = access_token
        self.session = session or requests.Session()
        self.timeout = timeout
        self.guessed_letters = []
        
        full_dictionary_location = "words_250000_train.txt"
        self.full_dictionary = self.build_dictionary(full_dictionary_location)        
        self.full_dictionary_common_letter_sorted = collections.Counter("".join(self.full_dictionary)).most_common()
        
        self.current_dictionary = []
        
    @staticmethod
    def determine_hangman_url():
        links = ['https://trexsim.com']

        data = {link: 0 for link in links}

        for link in links:

            requests.get(link)

            for i in range(10):
                s = time.time()
                requests.get(link)
                data[link] = time.time() - s

        link = sorted(data.items(), key=lambda x: x[1])[0][0]
        link += '/trexsim/hangman'
        return link

    def guess(self, word, guessed_letters, YS = True): # word input example: "_ p p _ e "
        ###############################################
        # Replace with your own "guess" function here #
        ###############################################
        
        if YS:
            # with open("config.yaml", "r") as f:
            #     lines = f.readlines()

            # lines = [line if not line.startswith("agent_mode:") else "agent_mode: Subpattern_Greedy\n" for line in lines]

            # with open("config.yaml", "w") as f:
            #     f.writelines(lines)

            word = word.strip().replace(" ", "")  # Remove spaces
            return guess_YS(word, guessed_letters)

        # clean the word so that we strip away the space characters
        # replace "_" with "." as "." indicates any character in regular expressions
        clean_word = word[::2].replace("_",".")
        
        # find length of passed word
        len_word = len(clean_word)
        
        # grab current dictionary of possible words from self object, initialize new possible words dictionary to empty
        current_dictionary = self.current_dictionary
        new_dictionary = []
        
        # iterate through all of the words in the old plausible dictionary
        for dict_word in current_dictionary:
            # continue if the word is not of the appropriate length
            if len(dict_word) != len_word:
                continue
                
            # if dictionary word is a possible match then add it to the current dictionary
            if re.match(clean_word,dict_word):
                new_dictionary.append(dict_word)
        
        # overwrite old possible words dictionary with updated version
        self.current_dictionary = new_dictionary
        
        
        # count occurrence of all characters in possible word matches
        full_dict_string = "".join(new_dictionary)
        
        c = collections.Counter(full_dict_string)
        sorted_letter_count = c.most_common()                   
        
        guess_letter = '!'
        
        # return most frequently occurring letter in all possible words that hasn't been guessed yet
        for letter,instance_count in sorted_letter_count:
            if letter not in self.guessed_letters:
                guess_letter = letter
                break
            
        # if no word matches in training dictionary, default back to ordering of full dictionary
        if guess_letter == '!':
            sorted_letter_count = self.full_dictionary_common_letter_sorted
            for letter,instance_count in sorted_letter_count:
                if letter not in self.guessed_letters:
                    guess_letter = letter
                    break            
        
        return guess_letter

    ##########################################################
    # You'll likely not need to modify any of the code below #
    ##########################################################
    
    def build_dictionary(self, dictionary_file_location):
        text_file = open(dictionary_file_location,"r")
        full_dictionary = text_file.read().splitlines()
        text_file.close()
        return full_dictionary
                
    def start_game(self, practice=True, verbose=True):
        # reset guessed letters to empty set and current plausible dictionary to the full dictionary
        self.guessed_letters = []
        self.current_dictionary = self.full_dictionary
                         
        response = self.request("/new_game", {"practice":practice})
        if response.get('status')=="approved":
            game_id = response.get('game_id')
            word = response.get('word')
            tries_remains = response.get('tries_remains')
            if verbose:
                print("Successfully start a new game! Game ID: {0}. # of tries remaining: {1}. Word: {2}.".format(game_id, tries_remains, word))
            while tries_remains>0:
                # get guessed letter from user code
                guess_letter = self.guess(word,self.guessed_letters)
                    
                # append guessed letter to guessed letters field in hangman object
                self.guessed_letters.append(guess_letter)
                if verbose:
                    print("Guessing letter: {0}".format(guess_letter))
                    
                try:    
                    res = self.request("/guess_letter", {"request":"guess_letter", "game_id":game_id, "letter":guess_letter})
                except HangmanAPIError:
                    print('HangmanAPIError exception caught on request.')
                    continue
                except Exception as e:
                    print('Other exception caught on request.')
                    raise e
               
                if verbose:
                    print("Sever response: {0}".format(res))
                status = res.get('status')
                tries_remains = res.get('tries_remains')
                if status=="success":
                    if verbose:
                        print("Successfully finished game: {0}".format(game_id))
                    return True
                elif status=="failed":
                    reason = res.get('reason', '# of tries exceeded!')
                    if verbose:
                        print("Failed game: {0}. Because of: {1}".format(game_id, reason))
                    return False
                elif status=="ongoing":
                    word = res.get('word')
        else:
            if verbose:
                print("Failed to start a new game")
        return status=="success"
        
    def my_status(self):
        return self.request("/my_status", {})
    
    def request(
            self, path, args=None, post_args=None, method=None):
        if args is None:
            args = dict()
        if post_args is not None:
            method = "POST"

        # Add `access_token` to post_args or args if it has not already been
        # included.
        if self.access_token:
            # If post_args exists, we assume that args either does not exists
            # or it does not need `access_token`.
            if post_args and "access_token" not in post_args:
                post_args["access_token"] = self.access_token
            elif "access_token" not in args:
                args["access_token"] = self.access_token

        time.sleep(0.2)

        num_retry, time_sleep = 50, 2
        for it in range(num_retry):
            try:
                response = self.session.request(
                    method or "GET",
                    self.hangman_url + path,
                    timeout=self.timeout,
                    params=args,
                    data=post_args,
                    verify=False
                )
                break
            except requests.HTTPError as e:
                response = json.loads(e.read())
                raise HangmanAPIError(response)
            except requests.exceptions.SSLError as e:
                if it + 1 == num_retry:
                    raise
                time.sleep(time_sleep)

        headers = response.headers
        if 'json' in headers['content-type']:
            result = response.json()
        elif "access_token" in parse_qs(response.text):
            query_str = parse_qs(response.text)
            if "access_token" in query_str:
                result = {"access_token": query_str["access_token"][0]}
                if "expires" in query_str:
                    result["expires"] = query_str["expires"][0]
            else:
                raise HangmanAPIError(response.json())
        else:
            raise HangmanAPIError('Maintype was not text, or querystring')

        if result and isinstance(result, dict) and result.get("error"):
            raise HangmanAPIError(result)
        return result
    
class HangmanAPIError(Exception):
    def __init__(self, result):
        self.result = result
        self.code = None
        try:
            self.type = result["error_code"]
        except (KeyError, TypeError):
            self.type = ""

        try:
            self.message = result["error_description"]
        except (KeyError, TypeError):
            try:
                self.message = result["error"]["message"]
                self.code = result["error"].get("code")
                if not self.type:
                    self.type = result["error"].get("type", "")
            except (KeyError, TypeError):
                try:
                    self.message = result["error_msg"]
                except (KeyError, TypeError):
                    self.message = result

        Exception.__init__(self, self.message)

# %% [markdown]
# # API Usage Examples

# %% [markdown]
# ## To start a new game:
# 1. Make sure you have implemented your own "guess" method.
# 2. Use the access_token that we sent you to create your HangmanAPI object.
# 3. Start a game by calling "start_game" method.
# 4. If you wish to test your function without being recorded, set "practice" parameter to 1.
# 5. Note: You have a rate limit of 20 new games per minute. DO NOT start more than 20 new games within one minute.

# %%
api = HangmanAPI(access_token="60f0e522873b5153cb4dbee0e497dd", timeout=2000)

# %% [markdown]
# ## Playing practice games:
# You can use the command below to play up to 100,000 practice games.

# %%
for i in range(1000):
    print('Playing ', i, ' th game')
    api.start_game(practice=1,verbose=False)
    [total_practice_runs,total_recorded_runs,total_recorded_successes,total_practice_successes] = api.my_status() # Get my game stats: (# of tries, # of wins)
    practice_success_rate = total_practice_successes / total_practice_runs
    print('run %d practice games out of an allotted 100,000. practice success rate so far = %.3f' % (total_practice_runs, practice_success_rate))
    time.sleep(0.5)
# Out:
# Playing  0  th game
# run 170 practice games out of an allotted 100,000. practice success rate so far = 0.212
# Playing  1  th game
# run 171 practice games out of an allotted 100,000. practice success rate so far = 0.211
# Playing  2  th game
# run 172 practice games out of an allotted 100,000. practice success rate so far = 0.209
# Playing  3  th game
# run 173 practice games out of an allotted 100,000. practice success rate so far = 0.214
# Playing  4  th game
# run 174 practice games out of an allotted 100,000. practice success rate so far = 0.213
# Playing  5  th game
# run 175 practice games out of an allotted 100,000. practice success rate so far = 0.211
# Playing  6  th game
# run 176 practice games out of an allotted 100,000. practice success rate so far = 0.210
# Playing  7  th game
# run 177 practice games out of an allotted 100,000. practice success rate so far = 0.215
# Playing  8  th game
# run 178 practice games out of an allotted 100,000. practice success rate so far = 0.213
# Playing  9  th game
# run 179 practice games out of an allotted 100,000. practice success rate so far = 0.212
# Playing  10  th game
# run 180 practice games out of an allotted 100,000. practice success rate so far = 0.211
# Playing  11  th game
# run 181 practice games out of an allotted 100,000. practice success rate so far = 0.210
# Playing  12  th game
# run 182 practice games out of an allotted 100,000. practice success rate so far = 0.209
# Playing  13  th game
# run 183 practice games out of an allotted 100,000. practice success rate so far = 0.208
# Playing  14  th game
# run 184 practice games out of an allotted 100,000. practice success rate so far = 0.212
# Playing  15  th game
# run 185 practice games out of an allotted 100,000. practice success rate so far = 0.211
# Playing  16  th game
# run 186 practice games out of an allotted 100,000. practice success rate so far = 0.215
# Playing  17  th game
# run 187 practice games out of an allotted 100,000. practice success rate so far = 0.214
# Playing  18  th game
# run 188 practice games out of an allotted 100,000. practice success rate so far = 0.213
# Playing  19  th game
# run 189 practice games out of an allotted 100,000. practice success rate so far = 0.217
# Playing  20  th game
# run 190 practice games out of an allotted 100,000. practice success rate so far = 0.221
# Playing  21  th game
# run 191 practice games out of an allotted 100,000. practice success rate so far = 0.220
# Playing  22  th game
# run 192 practice games out of an allotted 100,000. practice success rate so far = 0.219
# Playing  23  th game
# run 193 practice games out of an allotted 100,000. practice success rate so far = 0.218
# Playing  24  th game
# run 194 practice games out of an allotted 100,000. practice success rate so far = 0.222
# Playing  25  th game
# run 195 practice games out of an allotted 100,000. practice success rate so far = 0.221
# Playing  26  th game
# run 196 practice games out of an allotted 100,000. practice success rate so far = 0.219
# Playing  27  th game
# run 197 practice games out of an allotted 100,000. practice success rate so far = 0.218
# Playing  28  th game
# run 198 practice games out of an allotted 100,000. practice success rate so far = 0.222
# Playing  29  th game
# run 199 practice games out of an allotted 100,000. practice success rate so far = 0.226
# Playing  30  th game
# run 200 practice games out of an allotted 100,000. practice success rate so far = 0.230
# Playing  31  th game
# run 201 practice games out of an allotted 100,000. practice success rate so far = 0.229
# Playing  32  th game
# run 202 practice games out of an allotted 100,000. practice success rate so far = 0.228
# Playing  33  th game
# run 203 practice games out of an allotted 100,000. practice success rate so far = 0.227
# Playing  34  th game
# run 204 practice games out of an allotted 100,000. practice success rate so far = 0.225
# Playing  35  th game
# run 205 practice games out of an allotted 100,000. practice success rate so far = 0.224
# Playing  36  th game
# run 206 practice games out of an allotted 100,000. practice success rate so far = 0.223
# Playing  37  th game
# run 207 practice games out of an allotted 100,000. practice success rate so far = 0.222
# Playing  38  th game
# run 208 practice games out of an allotted 100,000. practice success rate so far = 0.221
# Playing  39  th game
# run 209 practice games out of an allotted 100,000. practice success rate so far = 0.225
# Playing  40  th game
# run 210 practice games out of an allotted 100,000. practice success rate so far = 0.229
# Playing  41  th game
# run 211 practice games out of an allotted 100,000. practice success rate so far = 0.227
# Playing  42  th game
# run 212 practice games out of an allotted 100,000. practice success rate so far = 0.226
# Playing  43  th game
# run 213 practice games out of an allotted 100,000. practice success rate so far = 0.225
# Playing  44  th game
# run 214 practice games out of an allotted 100,000. practice success rate so far = 0.229
# Playing  45  th game
# run 215 practice games out of an allotted 100,000. practice success rate so far = 0.233
# Playing  46  th game
# run 216 practice games out of an allotted 100,000. practice success rate so far = 0.236
# Playing  47  th game
# run 217 practice games out of an allotted 100,000. practice success rate so far = 0.235
# Playing  48  th game
# run 218 practice games out of an allotted 100,000. practice success rate so far = 0.234
# Playing  49  th game
# run 219 practice games out of an allotted 100,000. practice success rate so far = 0.233
# Playing  50  th game
# run 220 practice games out of an allotted 100,000. practice success rate so far = 0.232
# Playing  51  th game
# run 221 practice games out of an allotted 100,000. practice success rate so far = 0.231
# Playing  52  th game
# run 222 practice games out of an allotted 100,000. practice success rate so far = 0.230
# Playing  53  th game
# run 223 practice games out of an allotted 100,000. practice success rate so far = 0.229
# Playing  54  th game
# run 224 practice games out of an allotted 100,000. practice success rate so far = 0.228
# Playing  55  th game
# run 225 practice games out of an allotted 100,000. practice success rate so far = 0.227
# Playing  56  th game
# run 226 practice games out of an allotted 100,000. practice success rate so far = 0.226
# Playing  57  th game
# run 227 practice games out of an allotted 100,000. practice success rate so far = 0.225
# Playing  58  th game
# run 228 practice games out of an allotted 100,000. practice success rate so far = 0.228
# Playing  59  th game
# run 229 practice games out of an allotted 100,000. practice success rate so far = 0.231
# Playing  60  th game
# run 230 practice games out of an allotted 100,000. practice success rate so far = 0.235
# Playing  61  th game
# run 231 practice games out of an allotted 100,000. practice success rate so far = 0.234
# Playing  62  th game
# run 232 practice games out of an allotted 100,000. practice success rate so far = 0.237
# Playing  63  th game
# run 233 practice games out of an allotted 100,000. practice success rate so far = 0.236
# Playing  64  th game
# run 234 practice games out of an allotted 100,000. practice success rate so far = 0.239
# Playing  65  th game
# run 235 practice games out of an allotted 100,000. practice success rate so far = 0.238
# Playing  66  th game
# run 236 practice games out of an allotted 100,000. practice success rate so far = 0.237
# Playing  67  th game
# run 237 practice games out of an allotted 100,000. practice success rate so far = 0.236
# Playing  68  th game
# run 238 practice games out of an allotted 100,000. practice success rate so far = 0.235
# Playing  69  th game
# run 239 practice games out of an allotted 100,000. practice success rate so far = 0.238
# Playing  70  th game
# run 240 practice games out of an allotted 100,000. practice success rate so far = 0.237
# Playing  71  th game
# run 241 practice games out of an allotted 100,000. practice success rate so far = 0.241
# Playing  72  th game
# run 242 practice games out of an allotted 100,000. practice success rate so far = 0.244
# Playing  73  th game
# run 243 practice games out of an allotted 100,000. practice success rate so far = 0.243
# Playing  74  th game
# run 244 practice games out of an allotted 100,000. practice success rate so far = 0.242
# Playing  75  th game
# run 245 practice games out of an allotted 100,000. practice success rate so far = 0.241
# Playing  76  th game
# run 246 practice games out of an allotted 100,000. practice success rate so far = 0.244
# Playing  77  th game
# run 247 practice games out of an allotted 100,000. practice success rate so far = 0.247
# Playing  78  th game
# run 248 practice games out of an allotted 100,000. practice success rate so far = 0.246
# Playing  79  th game
# run 249 practice games out of an allotted 100,000. practice success rate so far = 0.245
# Playing  80  th game
# run 250 practice games out of an allotted 100,000. practice success rate so far = 0.244
# Playing  81  th game
# run 251 practice games out of an allotted 100,000. practice success rate so far = 0.247
# Playing  82  th game
# run 252 practice games out of an allotted 100,000. practice success rate so far = 0.246
# Playing  83  th game
# run 253 practice games out of an allotted 100,000. practice success rate so far = 0.245
# Playing  84  th game
# run 254 practice games out of an allotted 100,000. practice success rate so far = 0.244
# Playing  85  th game
# run 255 practice games out of an allotted 100,000. practice success rate so far = 0.243
# Playing  86  th game
# run 256 practice games out of an allotted 100,000. practice success rate so far = 0.246
# Playing  87  th game
# run 257 practice games out of an allotted 100,000. practice success rate so far = 0.245
# Playing  88  th game
# run 258 practice games out of an allotted 100,000. practice success rate so far = 0.248
# Playing  89  th game
# run 259 practice games out of an allotted 100,000. practice success rate so far = 0.251
# Playing  90  th game
# run 260 practice games out of an allotted 100,000. practice success rate so far = 0.250
# Playing  91  th game
# run 261 practice games out of an allotted 100,000. practice success rate so far = 0.249
# Playing  92  th game
# run 262 practice games out of an allotted 100,000. practice success rate so far = 0.252
# Playing  93  th game
# run 263 practice games out of an allotted 100,000. practice success rate so far = 0.251
# Playing  94  th game
# run 264 practice games out of an allotted 100,000. practice success rate so far = 0.250
# Playing  95  th game
# run 265 practice games out of an allotted 100,000. practice success rate so far = 0.253
# Playing  96  th game
# run 266 practice games out of an allotted 100,000. practice success rate so far = 0.256
# Playing  97  th game
# run 267 practice games out of an allotted 100,000. practice success rate so far = 0.255
# Playing  98  th game
# run 268 practice games out of an allotted 100,000. practice success rate so far = 0.254
# Playing  99  th game
# run 269 practice games out of an allotted 100,000. practice success rate so far = 0.253
# Playing  100  th game
# run 270 practice games out of an allotted 100,000. practice success rate so far = 0.256
# Playing  101  th game
# run 271 practice games out of an allotted 100,000. practice success rate so far = 0.255
# Playing  102  th game
# run 272 practice games out of an allotted 100,000. practice success rate so far = 0.254
# Playing  103  th game
# run 273 practice games out of an allotted 100,000. practice success rate so far = 0.253
# Playing  104  th game
# run 274 practice games out of an allotted 100,000. practice success rate so far = 0.252
# Playing  105  th game
# run 275 practice games out of an allotted 100,000. practice success rate so far = 0.255
# Playing  106  th game
# run 276 practice games out of an allotted 100,000. practice success rate so far = 0.257
# Playing  107  th game
# run 277 practice games out of an allotted 100,000. practice success rate so far = 0.256
# Playing  108  th game
# run 278 practice games out of an allotted 100,000. practice success rate so far = 0.255
# Playing  109  th game
# run 279 practice games out of an allotted 100,000. practice success rate so far = 0.258
# Playing  110  th game
# run 280 practice games out of an allotted 100,000. practice success rate so far = 0.257
# Playing  111  th game
# run 281 practice games out of an allotted 100,000. practice success rate so far = 0.256
# Playing  112  th game
# run 282 practice games out of an allotted 100,000. practice success rate so far = 0.255
# Playing  113  th game
# run 283 practice games out of an allotted 100,000. practice success rate so far = 0.254
# Playing  114  th game
# run 284 practice games out of an allotted 100,000. practice success rate so far = 0.254
# Playing  115  th game
# run 285 practice games out of an allotted 100,000. practice success rate so far = 0.253
# Playing  116  th game
# run 286 practice games out of an allotted 100,000. practice success rate so far = 0.252
# Playing  117  th game
# run 287 practice games out of an allotted 100,000. practice success rate so far = 0.254
# Playing  118  th game
# run 288 practice games out of an allotted 100,000. practice success rate so far = 0.253
# Playing  119  th game
# run 289 practice games out of an allotted 100,000. practice success rate so far = 0.253
# Playing  120  th game
# run 290 practice games out of an allotted 100,000. practice success rate so far = 0.255
# Playing  121  th game
# run 291 practice games out of an allotted 100,000. practice success rate so far = 0.254
# Playing  122  th game
# run 292 practice games out of an allotted 100,000. practice success rate so far = 0.253
# Playing  123  th game
# run 293 practice games out of an allotted 100,000. practice success rate so far = 0.253
# Playing  124  th game
# run 294 practice games out of an allotted 100,000. practice success rate so far = 0.255
# Playing  125  th game
# run 295 practice games out of an allotted 100,000. practice success rate so far = 0.254
# Playing  126  th game
# run 296 practice games out of an allotted 100,000. practice success rate so far = 0.253
# Playing  127  th game
# run 297 practice games out of an allotted 100,000. practice success rate so far = 0.256
# Playing  128  th game
# run 298 practice games out of an allotted 100,000. practice success rate so far = 0.255
# Playing  129  th game
# run 299 practice games out of an allotted 100,000. practice success rate so far = 0.254
# Playing  130  th game
# run 300 practice games out of an allotted 100,000. practice success rate so far = 0.253
# Playing  131  th game
# run 301 practice games out of an allotted 100,000. practice success rate so far = 0.256
# Playing  132  th game
# run 302 practice games out of an allotted 100,000. practice success rate so far = 0.258
# Playing  133  th game
# run 303 practice games out of an allotted 100,000. practice success rate so far = 0.257
# Playing  134  th game
# run 304 practice games out of an allotted 100,000. practice success rate so far = 0.260
# Playing  135  th game
# run 305 practice games out of an allotted 100,000. practice success rate so far = 0.259
# Playing  136  th game
# run 306 practice games out of an allotted 100,000. practice success rate so far = 0.258
# Playing  137  th game
# run 307 practice games out of an allotted 100,000. practice success rate so far = 0.257
# Playing  138  th game
# run 308 practice games out of an allotted 100,000. practice success rate so far = 0.256
# Playing  139  th game
# run 309 practice games out of an allotted 100,000. practice success rate so far = 0.256
# Playing  140  th game
# run 310 practice games out of an allotted 100,000. practice success rate so far = 0.255
# Playing  141  th game
# run 311 practice games out of an allotted 100,000. practice success rate so far = 0.254
# Playing  142  th game
# run 312 practice games out of an allotted 100,000. practice success rate so far = 0.256
# Playing  143  th game
# run 313 practice games out of an allotted 100,000. practice success rate so far = 0.256
# Playing  144  th game
# run 314 practice games out of an allotted 100,000. practice success rate so far = 0.255
# Playing  145  th game
# run 315 practice games out of an allotted 100,000. practice success rate so far = 0.254
# Playing  146  th game
# run 316 practice games out of an allotted 100,000. practice success rate so far = 0.253
# Playing  147  th game
# run 317 practice games out of an allotted 100,000. practice success rate so far = 0.252
# Playing  148  th game
# run 318 practice games out of an allotted 100,000. practice success rate so far = 0.252
# Playing  149  th game
# run 319 practice games out of an allotted 100,000. practice success rate so far = 0.251
# Playing  150  th game
# run 320 practice games out of an allotted 100,000. practice success rate so far = 0.250
# Playing  151  th game
# run 321 practice games out of an allotted 100,000. practice success rate so far = 0.252
# Playing  152  th game
# run 322 practice games out of an allotted 100,000. practice success rate so far = 0.252
# Playing  153  th game
# run 323 practice games out of an allotted 100,000. practice success rate so far = 0.251
# Playing  154  th game
# run 324 practice games out of an allotted 100,000. practice success rate so far = 0.250
# Playing  155  th game
# run 325 practice games out of an allotted 100,000. practice success rate so far = 0.249
# Playing  156  th game
# run 326 practice games out of an allotted 100,000. practice success rate so far = 0.248
# Playing  157  th game
# run 327 practice games out of an allotted 100,000. practice success rate so far = 0.248
# Playing  158  th game
# run 328 practice games out of an allotted 100,000. practice success rate so far = 0.247
# Playing  159  th game
# run 329 practice games out of an allotted 100,000. practice success rate so far = 0.249
# Playing  160  th game
# run 330 practice games out of an allotted 100,000. practice success rate so far = 0.248
# Playing  161  th game
# run 331 practice games out of an allotted 100,000. practice success rate so far = 0.248
# Playing  162  th game
# run 332 practice games out of an allotted 100,000. practice success rate so far = 0.247
# Playing  163  th game
# run 333 practice games out of an allotted 100,000. practice success rate so far = 0.249
# Playing  164  th game
# run 334 practice games out of an allotted 100,000. practice success rate so far = 0.251
# Playing  165  th game
# run 335 practice games out of an allotted 100,000. practice success rate so far = 0.251
# Playing  166  th game
# run 336 practice games out of an allotted 100,000. practice success rate so far = 0.250
# Playing  167  th game
# run 337 practice games out of an allotted 100,000. practice success rate so far = 0.249
# Playing  168  th game
# run 338 practice games out of an allotted 100,000. practice success rate so far = 0.249
# Playing  169  th game
# run 339 practice games out of an allotted 100,000. practice success rate so far = 0.248
# Playing  170  th game
# run 340 practice games out of an allotted 100,000. practice success rate so far = 0.247
# Playing  171  th game
# run 341 practice games out of an allotted 100,000. practice success rate so far = 0.246
# Playing  172  th game
# run 342 practice games out of an allotted 100,000. practice success rate so far = 0.249
# Playing  173  th game
# run 343 practice games out of an allotted 100,000. practice success rate so far = 0.248
# Playing  174  th game
# run 344 practice games out of an allotted 100,000. practice success rate so far = 0.250
# Playing  175  th game
# run 345 practice games out of an allotted 100,000. practice success rate so far = 0.252
# Playing  176  th game
# run 346 practice games out of an allotted 100,000. practice success rate so far = 0.254
# Playing  177  th game
# run 347 practice games out of an allotted 100,000. practice success rate so far = 0.256
# Playing  178  th game
# run 348 practice games out of an allotted 100,000. practice success rate so far = 0.259
# Playing  179  th game
# run 349 practice games out of an allotted 100,000. practice success rate so far = 0.258
# Playing  180  th game
# run 350 practice games out of an allotted 100,000. practice success rate so far = 0.257
# Playing  181  th game
# run 351 practice games out of an allotted 100,000. practice success rate so far = 0.256
# Playing  182  th game
# run 352 practice games out of an allotted 100,000. practice success rate so far = 0.256
# Playing  183  th game
# run 353 practice games out of an allotted 100,000. practice success rate so far = 0.255
# Playing  184  th game
# run 354 practice games out of an allotted 100,000. practice success rate so far = 0.254
# Playing  185  th game
# run 355 practice games out of an allotted 100,000. practice success rate so far = 0.254
# Playing  186  th game
# run 356 practice games out of an allotted 100,000. practice success rate so far = 0.253
# Playing  187  th game
# run 357 practice games out of an allotted 100,000. practice success rate so far = 0.252
# Playing  188  th game
# run 358 practice games out of an allotted 100,000. practice success rate so far = 0.254
# Playing  189  th game
# run 359 practice games out of an allotted 100,000. practice success rate so far = 0.256
# Playing  190  th game
# run 360 practice games out of an allotted 100,000. practice success rate so far = 0.256
# Playing  191  th game
# run 361 practice games out of an allotted 100,000. practice success rate so far = 0.255
# Playing  192  th game
# run 362 practice games out of an allotted 100,000. practice success rate so far = 0.254
# Playing  193  th game
# run 363 practice games out of an allotted 100,000. practice success rate so far = 0.253
# Playing  194  th game
# run 364 practice games out of an allotted 100,000. practice success rate so far = 0.255
# Playing  195  th game
# run 365 practice games out of an allotted 100,000. practice success rate so far = 0.255
# Playing  196  th game
# run 366 practice games out of an allotted 100,000. practice success rate so far = 0.254
# Playing  197  th game
# run 367 practice games out of an allotted 100,000. practice success rate so far = 0.256
# Playing  198  th game
# run 368 practice games out of an allotted 100,000. practice success rate so far = 0.258
# Playing  199  th game
# run 369 practice games out of an allotted 100,000. practice success rate so far = 0.257
# Playing  200  th game
# run 370 practice games out of an allotted 100,000. practice success rate so far = 0.259
# Playing  201  th game
# run 371 practice games out of an allotted 100,000. practice success rate so far = 0.259
# Playing  202  th game
# run 372 practice games out of an allotted 100,000. practice success rate so far = 0.258
# Playing  203  th game
# run 373 practice games out of an allotted 100,000. practice success rate so far = 0.260
# Playing  204  th game
# run 374 practice games out of an allotted 100,000. practice success rate so far = 0.259
# Playing  205  th game
# run 375 practice games out of an allotted 100,000. practice success rate so far = 0.259
# Playing  206  th game
# run 376 practice games out of an allotted 100,000. practice success rate so far = 0.258
# Playing  207  th game
# run 377 practice games out of an allotted 100,000. practice success rate so far = 0.260
# Playing  208  th game
# run 378 practice games out of an allotted 100,000. practice success rate so far = 0.259
# Playing  209  th game
# run 379 practice games out of an allotted 100,000. practice success rate so far = 0.261
# Playing  210  th game
# run 380 practice games out of an allotted 100,000. practice success rate so far = 0.261
# Playing  211  th game
# run 381 practice games out of an allotted 100,000. practice success rate so far = 0.260
# Playing  212  th game
# run 382 practice games out of an allotted 100,000. practice success rate so far = 0.259
# Playing  213  th game
# run 383 practice games out of an allotted 100,000. practice success rate so far = 0.258
# Playing  214  th game
# run 384 practice games out of an allotted 100,000. practice success rate so far = 0.258
# Playing  215  th game
# run 385 practice games out of an allotted 100,000. practice success rate so far = 0.257
# Playing  216  th game
# run 386 practice games out of an allotted 100,000. practice success rate so far = 0.256
# Playing  217  th game
# run 387 practice games out of an allotted 100,000. practice success rate so far = 0.256
# Playing  218  th game
# run 388 practice games out of an allotted 100,000. practice success rate so far = 0.255
# Playing  219  th game
# run 389 practice games out of an allotted 100,000. practice success rate so far = 0.254
# Playing  220  th game
# run 390 practice games out of an allotted 100,000. practice success rate so far = 0.256
# Playing  221  th game
# run 391 practice games out of an allotted 100,000. practice success rate so far = 0.256
# Playing  222  th game
# run 392 practice games out of an allotted 100,000. practice success rate so far = 0.255
# Playing  223  th game
# run 393 practice games out of an allotted 100,000. practice success rate so far = 0.254
# Playing  224  th game
# run 394 practice games out of an allotted 100,000. practice success rate so far = 0.256
# Playing  225  th game
# run 395 practice games out of an allotted 100,000. practice success rate so far = 0.258
# Playing  226  th game
# run 396 practice games out of an allotted 100,000. practice success rate so far = 0.258
# Playing  227  th game
# run 397 practice games out of an allotted 100,000. practice success rate so far = 0.259
# Playing  228  th game
# run 398 practice games out of an allotted 100,000. practice success rate so far = 0.261
# Playing  229  th game
# run 399 practice games out of an allotted 100,000. practice success rate so far = 0.261
# Playing  230  th game
# run 400 practice games out of an allotted 100,000. practice success rate so far = 0.263
# Playing  231  th game
# run 401 practice games out of an allotted 100,000. practice success rate so far = 0.262
# Playing  232  th game
# run 402 practice games out of an allotted 100,000. practice success rate so far = 0.264
# Playing  233  th game
# run 403 practice games out of an allotted 100,000. practice success rate so far = 0.266
# Playing  234  th game
# run 404 practice games out of an allotted 100,000. practice success rate so far = 0.267
# Playing  235  th game
# run 405 practice games out of an allotted 100,000. practice success rate so far = 0.269
# Playing  236  th game
# run 406 practice games out of an allotted 100,000. practice success rate so far = 0.271
# Playing  237  th game
# run 407 practice games out of an allotted 100,000. practice success rate so far = 0.270
# Playing  238  th game
# run 408 practice games out of an allotted 100,000. practice success rate so far = 0.270
# Playing  239  th game
# run 409 practice games out of an allotted 100,000. practice success rate so far = 0.271
# Playing  240  th game
# run 410 practice games out of an allotted 100,000. practice success rate so far = 0.271
# Playing  241  th game
# run 411 practice games out of an allotted 100,000. practice success rate so far = 0.273
# Playing  242  th game
# run 412 practice games out of an allotted 100,000. practice success rate so far = 0.272
# Playing  243  th game
# run 413 practice games out of an allotted 100,000. practice success rate so far = 0.271
# Playing  244  th game
# run 414 practice games out of an allotted 100,000. practice success rate so far = 0.273
# Playing  245  th game
# run 415 practice games out of an allotted 100,000. practice success rate so far = 0.272
# Playing  246  th game
# run 416 practice games out of an allotted 100,000. practice success rate so far = 0.274
# Playing  247  th game
# run 417 practice games out of an allotted 100,000. practice success rate so far = 0.273
# Playing  248  th game
# run 418 practice games out of an allotted 100,000. practice success rate so far = 0.273
# Playing  249  th game
# run 419 practice games out of an allotted 100,000. practice success rate so far = 0.274
# Playing  250  th game
# run 420 practice games out of an allotted 100,000. practice success rate so far = 0.276
# Playing  251  th game
# run 421 practice games out of an allotted 100,000. practice success rate so far = 0.278
# Playing  252  th game
# run 422 practice games out of an allotted 100,000. practice success rate so far = 0.277
# Playing  253  th game
# run 423 practice games out of an allotted 100,000. practice success rate so far = 0.277
# Playing  254  th game
# run 424 practice games out of an allotted 100,000. practice success rate so far = 0.276
# Playing  255  th game
# run 425 practice games out of an allotted 100,000. practice success rate so far = 0.275
# Playing  256  th game
# run 426 practice games out of an allotted 100,000. practice success rate so far = 0.275
# Playing  257  th game
# run 427 practice games out of an allotted 100,000. practice success rate so far = 0.274
# Playing  258  th game
# run 428 practice games out of an allotted 100,000. practice success rate so far = 0.273
# Playing  259  th game
# run 429 practice games out of an allotted 100,000. practice success rate so far = 0.273
# Playing  260  th game
# run 430 practice games out of an allotted 100,000. practice success rate so far = 0.274
# Playing  261  th game
# run 431 practice games out of an allotted 100,000. practice success rate so far = 0.274
# Playing  262  th game
# run 432 practice games out of an allotted 100,000. practice success rate so far = 0.275
# Playing  263  th game
# run 433 practice games out of an allotted 100,000. practice success rate so far = 0.275
# Playing  264  th game
# run 434 practice games out of an allotted 100,000. practice success rate so far = 0.276
# Playing  265  th game
# run 435 practice games out of an allotted 100,000. practice success rate so far = 0.276
# Playing  266  th game
# run 436 practice games out of an allotted 100,000. practice success rate so far = 0.275
# Playing  267  th game
# run 437 practice games out of an allotted 100,000. practice success rate so far = 0.275
# Playing  268  th game
# run 438 practice games out of an allotted 100,000. practice success rate so far = 0.276
# Playing  269  th game
# run 439 practice games out of an allotted 100,000. practice success rate so far = 0.276
# Playing  270  th game
# run 440 practice games out of an allotted 100,000. practice success rate so far = 0.275
# Playing  271  th game
# run 441 practice games out of an allotted 100,000. practice success rate so far = 0.277
# Playing  272  th game
# run 442 practice games out of an allotted 100,000. practice success rate so far = 0.276
# Playing  273  th game
# run 443 practice games out of an allotted 100,000. practice success rate so far = 0.275
# Playing  274  th game
# run 444 practice games out of an allotted 100,000. practice success rate so far = 0.277
# Playing  275  th game
# run 445 practice games out of an allotted 100,000. practice success rate so far = 0.276
# Playing  276  th game
# run 446 practice games out of an allotted 100,000. practice success rate so far = 0.276
# Playing  277  th game
# run 447 practice games out of an allotted 100,000. practice success rate so far = 0.275
# Playing  278  th game
# run 448 practice games out of an allotted 100,000. practice success rate so far = 0.277
# Playing  279  th game
# run 449 practice games out of an allotted 100,000. practice success rate so far = 0.276
# Playing  280  th game
# run 450 practice games out of an allotted 100,000. practice success rate so far = 0.276
# Playing  281  th game
# run 451 practice games out of an allotted 100,000. practice success rate so far = 0.275
# Playing  282  th game
# run 452 practice games out of an allotted 100,000. practice success rate so far = 0.274
# Playing  283  th game
# run 453 practice games out of an allotted 100,000. practice success rate so far = 0.274
# Playing  284  th game
# run 454 practice games out of an allotted 100,000. practice success rate so far = 0.273
# Playing  285  th game
# run 455 practice games out of an allotted 100,000. practice success rate so far = 0.273
# Playing  286  th game
# run 456 practice games out of an allotted 100,000. practice success rate so far = 0.272
# Playing  287  th game
# run 457 practice games out of an allotted 100,000. practice success rate so far = 0.271
# Playing  288  th game
# run 458 practice games out of an allotted 100,000. practice success rate so far = 0.271
# Playing  289  th game
# run 459 practice games out of an allotted 100,000. practice success rate so far = 0.272
# Playing  290  th game
# run 460 practice games out of an allotted 100,000. practice success rate so far = 0.272
# Playing  291  th game
# run 461 practice games out of an allotted 100,000. practice success rate so far = 0.271
# Playing  292  th game
# run 462 practice games out of an allotted 100,000. practice success rate so far = 0.273
# Playing  293  th game
# run 463 practice games out of an allotted 100,000. practice success rate so far = 0.272
# Playing  294  th game
# run 464 practice games out of an allotted 100,000. practice success rate so far = 0.272
# Playing  295  th game
# run 465 practice games out of an allotted 100,000. practice success rate so far = 0.271
# Playing  296  th game
# run 466 practice games out of an allotted 100,000. practice success rate so far = 0.270
# Playing  297  th game
# run 467 practice games out of an allotted 100,000. practice success rate so far = 0.270
# Playing  298  th game
# run 468 practice games out of an allotted 100,000. practice success rate so far = 0.271
# Playing  299  th game
# run 469 practice games out of an allotted 100,000. practice success rate so far = 0.271
# Playing  300  th game
# run 470 practice games out of an allotted 100,000. practice success rate so far = 0.270
# Playing  301  th game
# run 471 practice games out of an allotted 100,000. practice success rate so far = 0.270
# Playing  302  th game
# run 472 practice games out of an allotted 100,000. practice success rate so far = 0.269
# Playing  303  th game
# run 473 practice games out of an allotted 100,000. practice success rate so far = 0.268
# Playing  304  th game
# run 474 practice games out of an allotted 100,000. practice success rate so far = 0.268
# Playing  305  th game
# run 475 practice games out of an allotted 100,000. practice success rate so far = 0.267
# Playing  306  th game
# run 476 practice games out of an allotted 100,000. practice success rate so far = 0.269
# Playing  307  th game
# run 477 practice games out of an allotted 100,000. practice success rate so far = 0.268
# Playing  308  th game
# run 478 practice games out of an allotted 100,000. practice success rate so far = 0.268
# Playing  309  th game
# run 479 practice games out of an allotted 100,000. practice success rate so far = 0.267
# Playing  310  th game
# run 480 practice games out of an allotted 100,000. practice success rate so far = 0.267
# Playing  311  th game
# run 481 practice games out of an allotted 100,000. practice success rate so far = 0.266
# Playing  312  th game
# run 482 practice games out of an allotted 100,000. practice success rate so far = 0.268
# Playing  313  th game
# run 483 practice games out of an allotted 100,000. practice success rate so far = 0.267
# Playing  314  th game
# run 484 practice games out of an allotted 100,000. practice success rate so far = 0.267
# Playing  315  th game
# run 485 practice games out of an allotted 100,000. practice success rate so far = 0.266
# Playing  316  th game
# run 486 practice games out of an allotted 100,000. practice success rate so far = 0.267
# Playing  317  th game
# run 487 practice games out of an allotted 100,000. practice success rate so far = 0.267
# Playing  318  th game
# run 488 practice games out of an allotted 100,000. practice success rate so far = 0.266
# Playing  319  th game
# run 489 practice games out of an allotted 100,000. practice success rate so far = 0.266
# Playing  320  th game
# run 490 practice games out of an allotted 100,000. practice success rate so far = 0.267
# Playing  321  th game
# run 491 practice games out of an allotted 100,000. practice success rate so far = 0.269
# Playing  322  th game
# run 492 practice games out of an allotted 100,000. practice success rate so far = 0.268
# Playing  323  th game
# run 493 practice games out of an allotted 100,000. practice success rate so far = 0.268
# Playing  324  th game
# run 494 practice games out of an allotted 100,000. practice success rate so far = 0.267
# Playing  325  th game
# run 495 practice games out of an allotted 100,000. practice success rate so far = 0.267
# Playing  326  th game
# run 496 practice games out of an allotted 100,000. practice success rate so far = 0.266
# Playing  327  th game
# run 497 practice games out of an allotted 100,000. practice success rate so far = 0.266
# Playing  328  th game
# run 498 practice games out of an allotted 100,000. practice success rate so far = 0.265
# Playing  329  th game
# run 499 practice games out of an allotted 100,000. practice success rate so far = 0.265
# Playing  330  th game
# run 500 practice games out of an allotted 100,000. practice success rate so far = 0.264
# Playing  331  th game
# run 501 practice games out of an allotted 100,000. practice success rate so far = 0.263
# Playing  332  th game
# run 502 practice games out of an allotted 100,000. practice success rate so far = 0.263
# Playing  333  th game
# run 503 practice games out of an allotted 100,000. practice success rate so far = 0.264
# Playing  334  th game
# run 504 practice games out of an allotted 100,000. practice success rate so far = 0.264
# Playing  335  th game
# run 505 practice games out of an allotted 100,000. practice success rate so far = 0.263
# Playing  336  th game
# run 506 practice games out of an allotted 100,000. practice success rate so far = 0.263
# Playing  337  th game
# run 507 practice games out of an allotted 100,000. practice success rate so far = 0.262
# Playing  338  th game
# run 508 practice games out of an allotted 100,000. practice success rate so far = 0.262
# Playing  339  th game
# run 509 practice games out of an allotted 100,000. practice success rate so far = 0.261
# Playing  340  th game
# run 510 practice games out of an allotted 100,000. practice success rate so far = 0.261
# Playing  341  th game
# run 511 practice games out of an allotted 100,000. practice success rate so far = 0.262
# Playing  342  th game
# run 512 practice games out of an allotted 100,000. practice success rate so far = 0.262
# Playing  343  th game
# run 513 practice games out of an allotted 100,000. practice success rate so far = 0.261
# Playing  344  th game
# run 514 practice games out of an allotted 100,000. practice success rate so far = 0.261
# Playing  345  th game
# run 515 practice games out of an allotted 100,000. practice success rate so far = 0.262
# Playing  346  th game
# run 516 practice games out of an allotted 100,000. practice success rate so far = 0.264
# Playing  347  th game
# run 517 practice games out of an allotted 100,000. practice success rate so far = 0.265
# Playing  348  th game
# run 518 practice games out of an allotted 100,000. practice success rate so far = 0.264
# Playing  349  th game
# run 519 practice games out of an allotted 100,000. practice success rate so far = 0.264
# Playing  350  th game
# run 520 practice games out of an allotted 100,000. practice success rate so far = 0.263
# Playing  351  th game
# run 521 practice games out of an allotted 100,000. practice success rate so far = 0.263
# Playing  352  th game
# run 522 practice games out of an allotted 100,000. practice success rate so far = 0.262
# Playing  353  th game
# run 523 practice games out of an allotted 100,000. practice success rate so far = 0.262
# Playing  354  th game
# run 524 practice games out of an allotted 100,000. practice success rate so far = 0.261
# Playing  355  th game
# run 525 practice games out of an allotted 100,000. practice success rate so far = 0.263
# Playing  356  th game
# run 526 practice games out of an allotted 100,000. practice success rate so far = 0.262
# Playing  357  th game
# run 527 practice games out of an allotted 100,000. practice success rate so far = 0.262
# Playing  358  th game
# run 528 practice games out of an allotted 100,000. practice success rate so far = 0.261
# Playing  359  th game
# run 529 practice games out of an allotted 100,000. practice success rate so far = 0.263
# Playing  360  th game
# run 530 practice games out of an allotted 100,000. practice success rate so far = 0.262
# Playing  361  th game
# run 531 practice games out of an allotted 100,000. practice success rate so far = 0.262
# Playing  362  th game
# run 532 practice games out of an allotted 100,000. practice success rate so far = 0.261
# Playing  363  th game
# run 533 practice games out of an allotted 100,000. practice success rate so far = 0.261
# Playing  364  th game
# run 534 practice games out of an allotted 100,000. practice success rate so far = 0.260
# Playing  365  th game
# run 535 practice games out of an allotted 100,000. practice success rate so far = 0.260
# Playing  366  th game
# run 536 practice games out of an allotted 100,000. practice success rate so far = 0.259
# Playing  367  th game
# run 537 practice games out of an allotted 100,000. practice success rate so far = 0.259
# Playing  368  th game
# run 538 practice games out of an allotted 100,000. practice success rate so far = 0.258
# Playing  369  th game
# run 539 practice games out of an allotted 100,000. practice success rate so far = 0.258
# Playing  370  th game
# run 540 practice games out of an allotted 100,000. practice success rate so far = 0.257
# Playing  371  th game
# run 541 practice games out of an allotted 100,000. practice success rate so far = 0.259
# Playing  372  th game
# run 542 practice games out of an allotted 100,000. practice success rate so far = 0.258
# Playing  373  th game
# run 543 practice games out of an allotted 100,000. practice success rate so far = 0.258
# Playing  374  th game
# run 544 practice games out of an allotted 100,000. practice success rate so far = 0.257
# Playing  375  th game
# run 545 practice games out of an allotted 100,000. practice success rate so far = 0.257
# Playing  376  th game
# run 546 practice games out of an allotted 100,000. practice success rate so far = 0.256
# Playing  377  th game
# run 547 practice games out of an allotted 100,000. practice success rate so far = 0.258
# Playing  378  th game
# run 548 practice games out of an allotted 100,000. practice success rate so far = 0.257
# Playing  379  th game
# run 549 practice games out of an allotted 100,000. practice success rate so far = 0.257
# Playing  380  th game
# run 550 practice games out of an allotted 100,000. practice success rate so far = 0.258
# Playing  381  th game
# run 551 practice games out of an allotted 100,000. practice success rate so far = 0.258
# Playing  382  th game
# run 552 practice games out of an allotted 100,000. practice success rate so far = 0.257
# Playing  383  th game
# run 553 practice games out of an allotted 100,000. practice success rate so far = 0.259
# Playing  384  th game
# run 554 practice games out of an allotted 100,000. practice success rate so far = 0.260
# Playing  385  th game
# run 555 practice games out of an allotted 100,000. practice success rate so far = 0.259
# Playing  386  th game
# run 556 practice games out of an allotted 100,000. practice success rate so far = 0.259
# Playing  387  th game
# run 557 practice games out of an allotted 100,000. practice success rate so far = 0.260
# Playing  388  th game
# run 558 practice games out of an allotted 100,000. practice success rate so far = 0.260
# Playing  389  th game
# run 559 practice games out of an allotted 100,000. practice success rate so far = 0.259
# Playing  390  th game
# run 560 practice games out of an allotted 100,000. practice success rate so far = 0.259
# Playing  391  th game
# run 561 practice games out of an allotted 100,000. practice success rate so far = 0.258
# Playing  392  th game
# run 562 practice games out of an allotted 100,000. practice success rate so far = 0.258
# Playing  393  th game
# run 563 practice games out of an allotted 100,000. practice success rate so far = 0.259
# Playing  394  th game
# run 564 practice games out of an allotted 100,000. practice success rate so far = 0.259
# Playing  395  th game
# run 565 practice games out of an allotted 100,000. practice success rate so far = 0.258
# Playing  396  th game
# run 566 practice games out of an allotted 100,000. practice success rate so far = 0.260
# Playing  397  th game
# run 567 practice games out of an allotted 100,000. practice success rate so far = 0.259
# Playing  398  th game
# run 568 practice games out of an allotted 100,000. practice success rate so far = 0.259
# Playing  399  th game
# run 569 practice games out of an allotted 100,000. practice success rate so far = 0.258
# Playing  400  th game
# run 570 practice games out of an allotted 100,000. practice success rate so far = 0.258
# Playing  401  th game
# run 571 practice games out of an allotted 100,000. practice success rate so far = 0.257
# Playing  402  th game
# run 572 practice games out of an allotted 100,000. practice success rate so far = 0.257
# Playing  403  th game
# run 573 practice games out of an allotted 100,000. practice success rate so far = 0.257
# Playing  404  th game
# run 574 practice games out of an allotted 100,000. practice success rate so far = 0.256
# Playing  405  th game
# run 575 practice games out of an allotted 100,000. practice success rate so far = 0.256
# Playing  406  th game
# run 576 practice games out of an allotted 100,000. practice success rate so far = 0.257
# Playing  407  th game
# run 577 practice games out of an allotted 100,000. practice success rate so far = 0.256
# Playing  408  th game
# run 578 practice games out of an allotted 100,000. practice success rate so far = 0.258
# Playing  409  th game
# run 579 practice games out of an allotted 100,000. practice success rate so far = 0.257
# Playing  410  th game
# run 580 practice games out of an allotted 100,000. practice success rate so far = 0.257
# Playing  411  th game
# run 581 practice games out of an allotted 100,000. practice success rate so far = 0.256
# Playing  412  th game
# run 582 practice games out of an allotted 100,000. practice success rate so far = 0.256
# Playing  413  th game
# run 583 practice games out of an allotted 100,000. practice success rate so far = 0.256
# Playing  414  th game
# run 584 practice games out of an allotted 100,000. practice success rate so far = 0.255
# Playing  415  th game
# run 585 practice games out of an allotted 100,000. practice success rate so far = 0.255
# Playing  416  th game
# run 586 practice games out of an allotted 100,000. practice success rate so far = 0.254
# Playing  417  th game
# run 587 practice games out of an allotted 100,000. practice success rate so far = 0.256
# Playing  418  th game
# run 588 practice games out of an allotted 100,000. practice success rate so far = 0.255
# Playing  419  th game
# run 589 practice games out of an allotted 100,000. practice success rate so far = 0.255
# Playing  420  th game
# run 590 practice games out of an allotted 100,000. practice success rate so far = 0.256
# Playing  421  th game
# run 591 practice games out of an allotted 100,000. practice success rate so far = 0.255
# Playing  422  th game
# run 592 practice games out of an allotted 100,000. practice success rate so far = 0.255
# Playing  423  th game
# run 593 practice games out of an allotted 100,000. practice success rate so far = 0.255
# Playing  424  th game
# run 594 practice games out of an allotted 100,000. practice success rate so far = 0.254
# Playing  425  th game
# run 595 practice games out of an allotted 100,000. practice success rate so far = 0.255
# Playing  426  th game
# run 596 practice games out of an allotted 100,000. practice success rate so far = 0.255
# Playing  427  th game
# run 597 practice games out of an allotted 100,000. practice success rate so far = 0.255
# Playing  428  th game
# run 598 practice games out of an allotted 100,000. practice success rate so far = 0.254
# Playing  429  th game
# run 599 practice games out of an allotted 100,000. practice success rate so far = 0.254
# Playing  430  th game
# run 600 practice games out of an allotted 100,000. practice success rate so far = 0.253
# Playing  431  th game
# run 601 practice games out of an allotted 100,000. practice success rate so far = 0.255
# Playing  432  th game
# run 602 practice games out of an allotted 100,000. practice success rate so far = 0.256
# Playing  433  th game
# run 603 practice games out of an allotted 100,000. practice success rate so far = 0.255
# Playing  434  th game
# run 604 practice games out of an allotted 100,000. practice success rate so far = 0.255
# Playing  435  th game
# run 605 practice games out of an allotted 100,000. practice success rate so far = 0.255
# Playing  436  th game
# run 606 practice games out of an allotted 100,000. practice success rate so far = 0.254
# Playing  437  th game
# ...
# Playing  856  th game
# run 1026 practice games out of an allotted 100,000. practice success rate so far = 0.268
# Playing  857  th game
# run 1027 practice games out of an allotted 100,000. practice success rate so far = 0.268
# Playing  858  th game
# run 1028 practice games out of an allotted 100,000. practice success rate so far = 0.268
# Playing  859  th game
# run 1029 practice games out of an allotted 100,000. practice success rate so far = 0.267
# Playing  860  th game
# run 1030 practice games out of an allotted 100,000. practice success rate so far = 0.267
# Playing  861  th game
# run 1031 practice games out of an allotted 100,000. practice success rate so far = 0.267
# Playing  862  th game
# run 1032 practice games out of an allotted 100,000. practice success rate so far = 0.266
# Playing  863  th game
# run 1033 practice games out of an allotted 100,000. practice success rate so far = 0.266
# Playing  864  th game
# run 1034 practice games out of an allotted 100,000. practice success rate so far = 0.266
# Playing  865  th game
# run 1035 practice games out of an allotted 100,000. practice success rate so far = 0.266
# Playing  866  th game
# run 1036 practice games out of an allotted 100,000. practice success rate so far = 0.265
# Playing  867  th game
# run 1037 practice games out of an allotted 100,000. practice success rate so far = 0.266
# Playing  868  th game
# run 1038 practice games out of an allotted 100,000. practice success rate so far = 0.266
# Playing  869  th game
# run 1039 practice games out of an allotted 100,000. practice success rate so far = 0.267
# Playing  870  th game
# run 1040 practice games out of an allotted 100,000. practice success rate so far = 0.266
# Playing  871  th game
# run 1041 practice games out of an allotted 100,000. practice success rate so far = 0.266
# Playing  872  th game
# run 1042 practice games out of an allotted 100,000. practice success rate so far = 0.266
# Playing  873  th game
# run 1043 practice games out of an allotted 100,000. practice success rate so far = 0.266
# Playing  874  th game
# run 1044 practice games out of an allotted 100,000. practice success rate so far = 0.265
# Playing  875  th game
# run 1045 practice games out of an allotted 100,000. practice success rate so far = 0.266
# Playing  876  th game
# run 1046 practice games out of an allotted 100,000. practice success rate so far = 0.266
# Playing  877  th game
# run 1047 practice games out of an allotted 100,000. practice success rate so far = 0.266
# Playing  878  th game
# run 1048 practice games out of an allotted 100,000. practice success rate so far = 0.265
# Playing  879  th game
# run 1049 practice games out of an allotted 100,000. practice success rate so far = 0.265
# Playing  880  th game
# run 1050 practice games out of an allotted 100,000. practice success rate so far = 0.265
# Playing  881  th game
# run 1051 practice games out of an allotted 100,000. practice success rate so far = 0.265
# Playing  882  th game
# run 1052 practice games out of an allotted 100,000. practice success rate so far = 0.264
# Playing  883  th game
# run 1053 practice games out of an allotted 100,000. practice success rate so far = 0.264
# Playing  884  th game
# run 1054 practice games out of an allotted 100,000. practice success rate so far = 0.264
# Playing  885  th game
# run 1055 practice games out of an allotted 100,000. practice success rate so far = 0.264
# Playing  886  th game
# run 1056 practice games out of an allotted 100,000. practice success rate so far = 0.263
# Playing  887  th game
# run 1057 practice games out of an allotted 100,000. practice success rate so far = 0.263
# Playing  888  th game
# run 1058 practice games out of an allotted 100,000. practice success rate so far = 0.263
# Playing  889  th game
# run 1059 practice games out of an allotted 100,000. practice success rate so far = 0.263
# Playing  890  th game
# run 1060 practice games out of an allotted 100,000. practice success rate so far = 0.263
# Playing  891  th game
# run 1061 practice games out of an allotted 100,000. practice success rate so far = 0.264
# Playing  892  th game
# run 1062 practice games out of an allotted 100,000. practice success rate so far = 0.264
# Playing  893  th game
# run 1063 practice games out of an allotted 100,000. practice success rate so far = 0.263
# Playing  894  th game
# run 1064 practice games out of an allotted 100,000. practice success rate so far = 0.263
# Playing  895  th game
# run 1065 practice games out of an allotted 100,000. practice success rate so far = 0.264
# Playing  896  th game
# run 1066 practice games out of an allotted 100,000. practice success rate so far = 0.265
# Playing  897  th game
# run 1067 practice games out of an allotted 100,000. practice success rate so far = 0.264
# Playing  898  th game
# run 1068 practice games out of an allotted 100,000. practice success rate so far = 0.264
# Playing  899  th game
# run 1069 practice games out of an allotted 100,000. practice success rate so far = 0.265
# Playing  900  th game
# run 1070 practice games out of an allotted 100,000. practice success rate so far = 0.264
# Playing  901  th game
# run 1071 practice games out of an allotted 100,000. practice success rate so far = 0.265
# Playing  902  th game
# run 1072 practice games out of an allotted 100,000. practice success rate so far = 0.265
# Playing  903  th game
# run 1073 practice games out of an allotted 100,000. practice success rate so far = 0.266
# Playing  904  th game
# run 1074 practice games out of an allotted 100,000. practice success rate so far = 0.265
# Playing  905  th game
# run 1075 practice games out of an allotted 100,000. practice success rate so far = 0.266
# Playing  906  th game
# run 1076 practice games out of an allotted 100,000. practice success rate so far = 0.266
# Playing  907  th game
# run 1077 practice games out of an allotted 100,000. practice success rate so far = 0.266
# Playing  908  th game
# run 1078 practice games out of an allotted 100,000. practice success rate so far = 0.266
# Playing  909  th game
# run 1079 practice games out of an allotted 100,000. practice success rate so far = 0.266
# Playing  910  th game
# run 1080 practice games out of an allotted 100,000. practice success rate so far = 0.266
# Playing  911  th game
# run 1081 practice games out of an allotted 100,000. practice success rate so far = 0.265
# Playing  912  th game
# run 1082 practice games out of an allotted 100,000. practice success rate so far = 0.265
# Playing  913  th game
# run 1083 practice games out of an allotted 100,000. practice success rate so far = 0.266
# Playing  914  th game
# run 1084 practice games out of an allotted 100,000. practice success rate so far = 0.267
# Playing  915  th game
# run 1085 practice games out of an allotted 100,000. practice success rate so far = 0.266
# Playing  916  th game
# run 1086 practice games out of an allotted 100,000. practice success rate so far = 0.266
# Playing  917  th game
# run 1087 practice games out of an allotted 100,000. practice success rate so far = 0.266
# Playing  918  th game
# run 1088 practice games out of an allotted 100,000. practice success rate so far = 0.267
# Playing  919  th game
# run 1089 practice games out of an allotted 100,000. practice success rate so far = 0.266
# Playing  920  th game
# run 1090 practice games out of an allotted 100,000. practice success rate so far = 0.267
# Playing  921  th game
# run 1091 practice games out of an allotted 100,000. practice success rate so far = 0.267
# Playing  922  th game
# run 1092 practice games out of an allotted 100,000. practice success rate so far = 0.267
# Playing  923  th game
# run 1093 practice games out of an allotted 100,000. practice success rate so far = 0.267
# Playing  924  th game
# run 1094 practice games out of an allotted 100,000. practice success rate so far = 0.267
# Playing  925  th game
# run 1095 practice games out of an allotted 100,000. practice success rate so far = 0.267
# Playing  926  th game
# run 1096 practice games out of an allotted 100,000. practice success rate so far = 0.266
# Playing  927  th game
# run 1097 practice games out of an allotted 100,000. practice success rate so far = 0.266
# Playing  928  th game
# run 1098 practice games out of an allotted 100,000. practice success rate so far = 0.267
# Playing  929  th game
# run 1099 practice games out of an allotted 100,000. practice success rate so far = 0.268
# Playing  930  th game
# run 1100 practice games out of an allotted 100,000. practice success rate so far = 0.267
# Playing  931  th game
# run 1101 practice games out of an allotted 100,000. practice success rate so far = 0.268
# Playing  932  th game
# run 1102 practice games out of an allotted 100,000. practice success rate so far = 0.268
# Playing  933  th game
# run 1103 practice games out of an allotted 100,000. practice success rate so far = 0.267
# Playing  934  th game
# run 1104 practice games out of an allotted 100,000. practice success rate so far = 0.267
# Playing  935  th game
# run 1105 practice games out of an allotted 100,000. practice success rate so far = 0.268
# Playing  936  th game
# run 1106 practice games out of an allotted 100,000. practice success rate so far = 0.268
# Playing  937  th game
# run 1107 practice games out of an allotted 100,000. practice success rate so far = 0.267
# Playing  938  th game
# run 1108 practice games out of an allotted 100,000. practice success rate so far = 0.267
# Playing  939  th game
# run 1109 practice games out of an allotted 100,000. practice success rate so far = 0.267
# Playing  940  th game
# run 1110 practice games out of an allotted 100,000. practice success rate so far = 0.267
# Playing  941  th game
# run 1111 practice games out of an allotted 100,000. practice success rate so far = 0.266
# Playing  942  th game
# run 1112 practice games out of an allotted 100,000. practice success rate so far = 0.267
# Playing  943  th game
# run 1113 practice games out of an allotted 100,000. practice success rate so far = 0.267
# Playing  944  th game
# run 1114 practice games out of an allotted 100,000. practice success rate so far = 0.267
# Playing  945  th game
# run 1115 practice games out of an allotted 100,000. practice success rate so far = 0.266
# Playing  946  th game
# run 1116 practice games out of an allotted 100,000. practice success rate so far = 0.266
# Playing  947  th game
# run 1117 practice games out of an allotted 100,000. practice success rate so far = 0.266
# Playing  948  th game
# run 1118 practice games out of an allotted 100,000. practice success rate so far = 0.266
# Playing  949  th game
# run 1119 practice games out of an allotted 100,000. practice success rate so far = 0.265
# Playing  950  th game
# run 1120 practice games out of an allotted 100,000. practice success rate so far = 0.265
# Playing  951  th game
# run 1121 practice games out of an allotted 100,000. practice success rate so far = 0.265
# Playing  952  th game
# run 1122 practice games out of an allotted 100,000. practice success rate so far = 0.266
# Playing  953  th game
# run 1123 practice games out of an allotted 100,000. practice success rate so far = 0.265
# Playing  954  th game
# run 1124 practice games out of an allotted 100,000. practice success rate so far = 0.265
# Playing  955  th game
# run 1125 practice games out of an allotted 100,000. practice success rate so far = 0.265
# Playing  956  th game
# run 1126 practice games out of an allotted 100,000. practice success rate so far = 0.266
# Playing  957  th game
# run 1127 practice games out of an allotted 100,000. practice success rate so far = 0.265
# Playing  958  th game
# run 1128 practice games out of an allotted 100,000. practice success rate so far = 0.265
# Playing  959  th game
# run 1129 practice games out of an allotted 100,000. practice success rate so far = 0.265
# Playing  960  th game
# run 1130 practice games out of an allotted 100,000. practice success rate so far = 0.265
# Playing  961  th game
# run 1131 practice games out of an allotted 100,000. practice success rate so far = 0.264
# Playing  962  th game
# run 1132 practice games out of an allotted 100,000. practice success rate so far = 0.264
# Playing  963  th game
# run 1133 practice games out of an allotted 100,000. practice success rate so far = 0.264
# Playing  964  th game
# run 1134 practice games out of an allotted 100,000. practice success rate so far = 0.265
# Playing  965  th game
# run 1135 practice games out of an allotted 100,000. practice success rate so far = 0.264
# Playing  966  th game
# run 1136 practice games out of an allotted 100,000. practice success rate so far = 0.265
# Playing  967  th game
# run 1137 practice games out of an allotted 100,000. practice success rate so far = 0.265
# Playing  968  th game
# run 1138 practice games out of an allotted 100,000. practice success rate so far = 0.265
# Playing  969  th game
# run 1139 practice games out of an allotted 100,000. practice success rate so far = 0.265
# Playing  970  th game
# run 1140 practice games out of an allotted 100,000. practice success rate so far = 0.265
# Playing  971  th game
# run 1141 practice games out of an allotted 100,000. practice success rate so far = 0.265
# Playing  972  th game
# run 1142 practice games out of an allotted 100,000. practice success rate so far = 0.264
# Playing  973  th game
# run 1143 practice games out of an allotted 100,000. practice success rate so far = 0.264
# Playing  974  th game
# run 1144 practice games out of an allotted 100,000. practice success rate so far = 0.264
# Playing  975  th game
# run 1145 practice games out of an allotted 100,000. practice success rate so far = 0.264
# Playing  976  th game
# run 1146 practice games out of an allotted 100,000. practice success rate so far = 0.264
# Playing  977  th game
# run 1147 practice games out of an allotted 100,000. practice success rate so far = 0.263
# Playing  978  th game
# run 1148 practice games out of an allotted 100,000. practice success rate so far = 0.263
# Playing  979  th game
# run 1149 practice games out of an allotted 100,000. practice success rate so far = 0.264
# Playing  980  th game
# run 1150 practice games out of an allotted 100,000. practice success rate so far = 0.263
# Playing  981  th game
# run 1151 practice games out of an allotted 100,000. practice success rate so far = 0.263
# Playing  982  th game
# run 1152 practice games out of an allotted 100,000. practice success rate so far = 0.264
# Playing  983  th game
# run 1153 practice games out of an allotted 100,000. practice success rate so far = 0.264
# Playing  984  th game
# run 1154 practice games out of an allotted 100,000. practice success rate so far = 0.263
# Playing  985  th game
# run 1155 practice games out of an allotted 100,000. practice success rate so far = 0.263
# Playing  986  th game
# run 1156 practice games out of an allotted 100,000. practice success rate so far = 0.264
# Playing  987  th game
# run 1157 practice games out of an allotted 100,000. practice success rate so far = 0.264
# Playing  988  th game
# run 1158 practice games out of an allotted 100,000. practice success rate so far = 0.264
# Playing  989  th game
# run 1159 practice games out of an allotted 100,000. practice success rate so far = 0.264
# Playing  990  th game
# run 1160 practice games out of an allotted 100,000. practice success rate so far = 0.264
# Playing  991  th game
# run 1161 practice games out of an allotted 100,000. practice success rate so far = 0.264
# Playing  992  th game
# run 1162 practice games out of an allotted 100,000. practice success rate so far = 0.263
# Playing  993  th game
# run 1163 practice games out of an allotted 100,000. practice success rate so far = 0.263
# Playing  994  th game
# run 1164 practice games out of an allotted 100,000. practice success rate so far = 0.263
# Playing  995  th game
# run 1165 practice games out of an allotted 100,000. practice success rate so far = 0.264
# Playing  996  th game
# run 1166 practice games out of an allotted 100,000. practice success rate so far = 0.263
# Playing  997  th game
# run 1167 practice games out of an allotted 100,000. practice success rate so far = 0.263
# Playing  998  th game
# run 1168 practice games out of an allotted 100,000. practice success rate so far = 0.263
# Playing  999  th game
# run 1169 practice games out of an allotted 100,000. practice success rate so far = 0.263

# %% [markdown]
# ## Playing recorded games:
# Please finalize your code prior to running the cell below. Once this code executes once successfully your submission will be finalized. Our system will not allow you to rerun any additional games.
#
# Please note that it is expected that after you successfully run this block of code that subsequent runs will result in the error message "Your account has been deactivated".
#
# Once you've run this section of the code your submission is complete. Please send us your source code via email.

# %%
for i in range(1000):
    print('Playing ', i, ' th game')
    # Uncomment the following line to execute your final runs. Do not do this until you are satisfied with your submission
    api.start_game(practice=0,verbose=False)
    
    # DO NOT REMOVE as otherwise the server may lock you out for too high frequency of requests
    time.sleep(0.5)
# Out:
# Playing  0  th game
# Playing  1  th game
# Playing  2  th game
# Playing  3  th game
# Playing  4  th game
# Playing  5  th game
# Playing  6  th game
# Playing  7  th game
# Playing  8  th game
# Playing  9  th game
# Playing  10  th game
# Playing  11  th game
# Playing  12  th game
# Playing  13  th game
# Playing  14  th game
# Playing  15  th game
# Playing  16  th game
# Playing  17  th game
# Playing  18  th game
# Playing  19  th game
# Playing  20  th game
# Playing  21  th game
# Playing  22  th game
# Playing  23  th game
# Playing  24  th game
# Playing  25  th game
# Playing  26  th game
# Playing  27  th game
# Playing  28  th game
# Playing  29  th game
# Playing  30  th game
# Playing  31  th game
# Playing  32  th game
# Playing  33  th game
# Playing  34  th game
# Playing  35  th game
# Playing  36  th game
# Playing  37  th game
# Playing  38  th game
# Playing  39  th game
# Playing  40  th game
# Playing  41  th game
# Playing  42  th game
# Playing  43  th game
# Playing  44  th game
# Playing  45  th game
# Playing  46  th game
# Playing  47  th game
# Playing  48  th game
# Playing  49  th game
# Playing  50  th game
# Playing  51  th game
# Playing  52  th game
# Playing  53  th game
# Playing  54  th game
# Playing  55  th game
# Playing  56  th game
# Playing  57  th game
# Playing  58  th game
# Playing  59  th game
# Playing  60  th game
# Playing  61  th game
# Playing  62  th game
# Playing  63  th game
# Playing  64  th game
# Playing  65  th game
# Playing  66  th game
# Playing  67  th game
# Playing  68  th game
# Playing  69  th game
# Playing  70  th game
# Playing  71  th game
# Playing  72  th game
# Playing  73  th game
# Playing  74  th game
# Playing  75  th game
# Playing  76  th game
# Playing  77  th game
# Playing  78  th game
# Playing  79  th game
# Playing  80  th game
# Playing  81  th game
# Playing  82  th game
# Playing  83  th game
# Playing  84  th game
# Playing  85  th game
# Playing  86  th game
# Playing  87  th game
# Playing  88  th game
# Playing  89  th game
# Playing  90  th game
# Playing  91  th game
# Playing  92  th game
# Playing  93  th game
# Playing  94  th game
# Playing  95  th game
# Playing  96  th game
# Playing  97  th game
# Playing  98  th game
# Playing  99  th game
# Playing  100  th game
# Playing  101  th game
# Playing  102  th game
# Playing  103  th game
# Playing  104  th game
# Playing  105  th game
# Playing  106  th game
# Playing  107  th game
# Playing  108  th game
# Playing  109  th game
# Playing  110  th game
# Playing  111  th game
# Playing  112  th game
# Playing  113  th game
# Playing  114  th game
# Playing  115  th game
# Playing  116  th game
# Playing  117  th game
# Playing  118  th game
# Playing  119  th game
# Playing  120  th game
# Playing  121  th game
# Playing  122  th game
# Playing  123  th game
# Playing  124  th game
# Playing  125  th game
# Playing  126  th game
# Playing  127  th game
# Playing  128  th game
# Playing  129  th game
# Playing  130  th game
# Playing  131  th game
# Playing  132  th game
# Playing  133  th game
# Playing  134  th game
# Playing  135  th game
# Playing  136  th game
# Playing  137  th game
# Playing  138  th game
# Playing  139  th game
# Playing  140  th game
# Playing  141  th game
# Playing  142  th game
# Playing  143  th game
# Playing  144  th game
# Playing  145  th game
# Playing  146  th game
# Playing  147  th game
# Playing  148  th game
# Playing  149  th game
# Playing  150  th game
# Playing  151  th game
# Playing  152  th game
# Playing  153  th game
# Playing  154  th game
# Playing  155  th game
# Playing  156  th game
# Playing  157  th game
# Playing  158  th game
# Playing  159  th game
# Playing  160  th game
# Playing  161  th game
# Playing  162  th game
# Playing  163  th game
# Playing  164  th game
# Playing  165  th game
# Playing  166  th game
# Playing  167  th game
# Playing  168  th game
# Playing  169  th game
# Playing  170  th game
# Playing  171  th game
# Playing  172  th game
# Playing  173  th game
# Playing  174  th game
# Playing  175  th game
# Playing  176  th game
# Playing  177  th game
# Playing  178  th game
# Playing  179  th game
# Playing  180  th game
# Playing  181  th game
# Playing  182  th game
# Playing  183  th game
# Playing  184  th game
# Playing  185  th game
# Playing  186  th game
# Playing  187  th game
# Playing  188  th game
# Playing  189  th game
# Playing  190  th game
# Playing  191  th game
# Playing  192  th game
# Playing  193  th game
# Playing  194  th game
# Playing  195  th game
# Playing  196  th game
# Playing  197  th game
# Playing  198  th game
# Playing  199  th game
# Playing  200  th game
# Playing  201  th game
# Playing  202  th game
# Playing  203  th game
# Playing  204  th game
# Playing  205  th game
# Playing  206  th game
# Playing  207  th game
# Playing  208  th game
# Playing  209  th game
# Playing  210  th game
# Playing  211  th game
# Playing  212  th game
# Playing  213  th game
# Playing  214  th game
# Playing  215  th game
# Playing  216  th game
# Playing  217  th game
# Playing  218  th game
# Playing  219  th game
# Playing  220  th game
# Playing  221  th game
# Playing  222  th game
# Playing  223  th game
# Playing  224  th game
# Playing  225  th game
# Playing  226  th game
# Playing  227  th game
# Playing  228  th game
# Playing  229  th game
# Playing  230  th game
# Playing  231  th game
# Playing  232  th game
# Playing  233  th game
# Playing  234  th game
# Playing  235  th game
# Playing  236  th game
# Playing  237  th game
# Playing  238  th game
# Playing  239  th game
# Playing  240  th game
# Playing  241  th game
# Playing  242  th game
# Playing  243  th game
# Playing  244  th game
# Playing  245  th game
# Playing  246  th game
# Playing  247  th game
# Playing  248  th game
# Playing  249  th game
# Playing  250  th game
# Playing  251  th game
# Playing  252  th game
# Playing  253  th game
# Playing  254  th game
# Playing  255  th game
# Playing  256  th game
# Playing  257  th game
# Playing  258  th game
# Playing  259  th game
# Playing  260  th game
# Playing  261  th game
# Playing  262  th game
# Playing  263  th game
# Playing  264  th game
# Playing  265  th game
# Playing  266  th game
# Playing  267  th game
# Playing  268  th game
# Playing  269  th game
# Playing  270  th game
# Playing  271  th game
# Playing  272  th game
# Playing  273  th game
# Playing  274  th game
# Playing  275  th game
# Playing  276  th game
# Playing  277  th game
# Playing  278  th game
# Playing  279  th game
# Playing  280  th game
# Playing  281  th game
# Playing  282  th game
# Playing  283  th game
# Playing  284  th game
# Playing  285  th game
# Playing  286  th game
# Playing  287  th game
# Playing  288  th game
# Playing  289  th game
# Playing  290  th game
# Playing  291  th game
# Playing  292  th game
# Playing  293  th game
# Playing  294  th game
# Playing  295  th game
# Playing  296  th game
# Playing  297  th game
# Playing  298  th game
# Playing  299  th game
# Playing  300  th game
# Playing  301  th game
# Playing  302  th game
# Playing  303  th game
# Playing  304  th game
# Playing  305  th game
# Playing  306  th game
# Playing  307  th game
# Playing  308  th game
# Playing  309  th game
# Playing  310  th game
# Playing  311  th game
# Playing  312  th game
# Playing  313  th game
# Playing  314  th game
# Playing  315  th game
# Playing  316  th game
# Playing  317  th game
# Playing  318  th game
# Playing  319  th game
# Playing  320  th game
# Playing  321  th game
# Playing  322  th game
# Playing  323  th game
# Playing  324  th game
# Playing  325  th game
# Playing  326  th game
# Playing  327  th game
# Playing  328  th game
# Playing  329  th game
# Playing  330  th game
# Playing  331  th game
# Playing  332  th game
# Playing  333  th game
# Playing  334  th game
# Playing  335  th game
# Playing  336  th game
# Playing  337  th game
# Playing  338  th game
# Playing  339  th game
# Playing  340  th game
# Playing  341  th game
# Playing  342  th game
# Playing  343  th game
# Playing  344  th game
# Playing  345  th game
# Playing  346  th game
# Playing  347  th game
# Playing  348  th game
# Playing  349  th game
# Playing  350  th game
# Playing  351  th game
# Playing  352  th game
# Playing  353  th game
# Playing  354  th game
# Playing  355  th game
# Playing  356  th game
# Playing  357  th game
# Playing  358  th game
# Playing  359  th game
# Playing  360  th game
# Playing  361  th game
# Playing  362  th game
# Playing  363  th game
# Playing  364  th game
# Playing  365  th game
# Playing  366  th game
# Playing  367  th game
# Playing  368  th game
# Playing  369  th game
# Playing  370  th game
# Playing  371  th game
# Playing  372  th game
# Playing  373  th game
# Playing  374  th game
# Playing  375  th game
# Playing  376  th game
# Playing  377  th game
# Playing  378  th game
# Playing  379  th game
# Playing  380  th game
# Playing  381  th game
# Playing  382  th game
# Playing  383  th game
# Playing  384  th game
# Playing  385  th game
# Playing  386  th game
# Playing  387  th game
# Playing  388  th game
# Playing  389  th game
# Playing  390  th game
# Playing  391  th game
# Playing  392  th game
# Playing  393  th game
# Playing  394  th game
# Playing  395  th game
# Playing  396  th game
# Playing  397  th game
# Playing  398  th game
# Playing  399  th game
# Playing  400  th game
# Playing  401  th game
# Playing  402  th game
# Playing  403  th game
# Playing  404  th game
# Playing  405  th game
# Playing  406  th game
# Playing  407  th game
# Playing  408  th game
# Playing  409  th game
# Playing  410  th game
# Playing  411  th game
# Playing  412  th game
# Playing  413  th game
# Playing  414  th game
# Playing  415  th game
# Playing  416  th game
# Playing  417  th game
# Playing  418  th game
# Playing  419  th game
# Playing  420  th game
# Playing  421  th game
# Playing  422  th game
# Playing  423  th game
# Playing  424  th game
# Playing  425  th game
# Playing  426  th game
# Playing  427  th game
# Playing  428  th game
# Playing  429  th game
# Playing  430  th game
# Playing  431  th game
# Playing  432  th game
# Playing  433  th game
# Playing  434  th game
# Playing  435  th game
# Playing  436  th game
# Playing  437  th game
# Playing  438  th game
# Playing  439  th game
# Playing  440  th game
# Playing  441  th game
# Playing  442  th game
# Playing  443  th game
# Playing  444  th game
# Playing  445  th game
# Playing  446  th game
# Playing  447  th game
# Playing  448  th game
# Playing  449  th game
# Playing  450  th game
# Playing  451  th game
# Playing  452  th game
# Playing  453  th game
# Playing  454  th game
# Playing  455  th game
# Playing  456  th game
# Playing  457  th game
# Playing  458  th game
# Playing  459  th game
# Playing  460  th game
# Playing  461  th game
# Playing  462  th game
# Playing  463  th game
# Playing  464  th game
# Playing  465  th game
# Playing  466  th game
# Playing  467  th game
# Playing  468  th game
# Playing  469  th game
# Playing  470  th game
# Playing  471  th game
# Playing  472  th game
# Playing  473  th game
# Playing  474  th game
# Playing  475  th game
# Playing  476  th game
# Playing  477  th game
# Playing  478  th game
# Playing  479  th game
# Playing  480  th game
# Playing  481  th game
# Playing  482  th game
# Playing  483  th game
# Playing  484  th game
# Playing  485  th game
# Playing  486  th game
# Playing  487  th game
# Playing  488  th game
# Playing  489  th game
# Playing  490  th game
# Playing  491  th game
# Playing  492  th game
# Playing  493  th game
# Playing  494  th game
# Playing  495  th game
# Playing  496  th game
# Playing  497  th game
# Playing  498  th game
# Playing  499  th game
# Playing  500  th game
# Playing  501  th game
# Playing  502  th game
# Playing  503  th game
# Playing  504  th game
# Playing  505  th game
# Playing  506  th game
# Playing  507  th game
# Playing  508  th game
# Playing  509  th game
# Playing  510  th game
# Playing  511  th game
# Playing  512  th game
# Playing  513  th game
# Playing  514  th game
# Playing  515  th game
# Playing  516  th game
# Playing  517  th game
# Playing  518  th game
# Playing  519  th game
# Playing  520  th game
# Playing  521  th game
# Playing  522  th game
# Playing  523  th game
# Playing  524  th game
# Playing  525  th game
# Playing  526  th game
# Playing  527  th game
# Playing  528  th game
# Playing  529  th game
# Playing  530  th game
# Playing  531  th game
# Playing  532  th game
# Playing  533  th game
# Playing  534  th game
# Playing  535  th game
# Playing  536  th game
# Playing  537  th game
# Playing  538  th game
# Playing  539  th game
# Playing  540  th game
# Playing  541  th game
# Playing  542  th game
# Playing  543  th game
# Playing  544  th game
# Playing  545  th game
# Playing  546  th game
# Playing  547  th game
# Playing  548  th game
# Playing  549  th game
# Playing  550  th game
# Playing  551  th game
# Playing  552  th game
# Playing  553  th game
# Playing  554  th game
# Playing  555  th game
# Playing  556  th game
# Playing  557  th game
# Playing  558  th game
# Playing  559  th game
# Playing  560  th game
# Playing  561  th game
# Playing  562  th game
# Playing  563  th game
# Playing  564  th game
# Playing  565  th game
# Playing  566  th game
# Playing  567  th game
# Playing  568  th game
# Playing  569  th game
# Playing  570  th game
# Playing  571  th game
# Playing  572  th game
# Playing  573  th game
# Playing  574  th game
# Playing  575  th game
# Playing  576  th game
# Playing  577  th game
# Playing  578  th game
# Playing  579  th game
# Playing  580  th game
# Playing  581  th game
# Playing  582  th game
# Playing  583  th game
# Playing  584  th game
# Playing  585  th game
# Playing  586  th game
# Playing  587  th game
# Playing  588  th game
# Playing  589  th game
# Playing  590  th game
# Playing  591  th game
# Playing  592  th game
# Playing  593  th game
# Playing  594  th game
# Playing  595  th game
# Playing  596  th game
# Playing  597  th game
# Playing  598  th game
# Playing  599  th game
# Playing  600  th game
# Playing  601  th game
# Playing  602  th game
# Playing  603  th game
# Playing  604  th game
# Playing  605  th game
# Playing  606  th game
# Playing  607  th game
# Playing  608  th game
# Playing  609  th game
# Playing  610  th game
# Playing  611  th game
# Playing  612  th game
# Playing  613  th game
# Playing  614  th game
# Playing  615  th game
# Playing  616  th game
# Playing  617  th game
# Playing  618  th game
# Playing  619  th game
# Playing  620  th game
# Playing  621  th game
# Playing  622  th game
# Playing  623  th game
# Playing  624  th game
# Playing  625  th game
# Playing  626  th game
# Playing  627  th game
# Playing  628  th game
# Playing  629  th game
# Playing  630  th game
# Playing  631  th game
# Playing  632  th game
# Playing  633  th game
# Playing  634  th game
# Playing  635  th game
# Playing  636  th game
# Playing  637  th game
# Playing  638  th game
# Playing  639  th game
# Playing  640  th game
# Playing  641  th game
# Playing  642  th game
# Playing  643  th game
# Playing  644  th game
# Playing  645  th game
# Playing  646  th game
# Playing  647  th game
# Playing  648  th game
# Playing  649  th game
# Playing  650  th game
# Playing  651  th game
# Playing  652  th game
# Playing  653  th game
# Playing  654  th game
# Playing  655  th game
# Playing  656  th game
# Playing  657  th game
# Playing  658  th game
# Playing  659  th game
# Playing  660  th game
# Playing  661  th game
# Playing  662  th game
# Playing  663  th game
# Playing  664  th game
# Playing  665  th game
# Playing  666  th game
# Playing  667  th game
# Playing  668  th game
# Playing  669  th game
# Playing  670  th game
# Playing  671  th game
# Playing  672  th game
# Playing  673  th game
# Playing  674  th game
# Playing  675  th game
# Playing  676  th game
# Playing  677  th game
# Playing  678  th game
# Playing  679  th game
# Playing  680  th game
# Playing  681  th game
# Playing  682  th game
# Playing  683  th game
# Playing  684  th game
# Playing  685  th game
# Playing  686  th game
# Playing  687  th game
# Playing  688  th game
# Playing  689  th game
# Playing  690  th game
# Playing  691  th game
# Playing  692  th game
# Playing  693  th game
# Playing  694  th game
# Playing  695  th game
# Playing  696  th game
# Playing  697  th game
# Playing  698  th game
# Playing  699  th game
# Playing  700  th game
# Playing  701  th game
# Playing  702  th game
# Playing  703  th game
# Playing  704  th game
# Playing  705  th game
# Playing  706  th game
# Playing  707  th game
# Playing  708  th game
# Playing  709  th game
# Playing  710  th game
# Playing  711  th game
# Playing  712  th game
# Playing  713  th game
# Playing  714  th game
# Playing  715  th game
# Playing  716  th game
# Playing  717  th game
# Playing  718  th game
# Playing  719  th game
# Playing  720  th game
# Playing  721  th game
# Playing  722  th game
# Playing  723  th game
# Playing  724  th game
# Playing  725  th game
# Playing  726  th game
# Playing  727  th game
# Playing  728  th game
# Playing  729  th game
# Playing  730  th game
# Playing  731  th game
# Playing  732  th game
# Playing  733  th game
# Playing  734  th game
# Playing  735  th game
# Playing  736  th game
# Playing  737  th game
# Playing  738  th game
# Playing  739  th game
# Playing  740  th game
# Playing  741  th game
# Playing  742  th game
# Playing  743  th game
# Playing  744  th game
# Playing  745  th game
# Playing  746  th game
# Playing  747  th game
# Playing  748  th game
# Playing  749  th game
# Playing  750  th game
# Playing  751  th game
# Playing  752  th game
# Playing  753  th game
# Playing  754  th game
# Playing  755  th game
# Playing  756  th game
# Playing  757  th game
# Playing  758  th game
# Playing  759  th game
# Playing  760  th game
# Playing  761  th game
# Playing  762  th game
# Playing  763  th game
# Playing  764  th game
# Playing  765  th game
# Playing  766  th game
# Playing  767  th game
# Playing  768  th game
# Playing  769  th game
# Playing  770  th game
# Playing  771  th game
# Playing  772  th game
# Playing  773  th game
# Playing  774  th game
# Playing  775  th game
# Playing  776  th game
# Playing  777  th game
# Playing  778  th game
# Playing  779  th game
# Playing  780  th game
# Playing  781  th game
# Playing  782  th game
# Playing  783  th game
# Playing  784  th game
# Playing  785  th game
# Playing  786  th game
# Playing  787  th game
# Playing  788  th game
# Playing  789  th game
# Playing  790  th game
# Playing  791  th game
# Playing  792  th game
# Playing  793  th game
# Playing  794  th game
# Playing  795  th game
# Playing  796  th game
# Playing  797  th game
# Playing  798  th game
# Playing  799  th game
# Playing  800  th game
# Playing  801  th game
# Playing  802  th game
# Playing  803  th game
# Playing  804  th game
# Playing  805  th game
# Playing  806  th game
# Playing  807  th game
# Playing  808  th game
# Playing  809  th game
# Playing  810  th game
# Playing  811  th game
# Playing  812  th game
# Playing  813  th game
# Playing  814  th game
# Playing  815  th game
# Playing  816  th game
# Playing  817  th game
# Playing  818  th game
# Playing  819  th game
# Playing  820  th game
# Playing  821  th game
# Playing  822  th game
# Playing  823  th game
# Playing  824  th game
# Playing  825  th game
# Playing  826  th game
# Playing  827  th game
# Playing  828  th game
# Playing  829  th game
# Playing  830  th game
# Playing  831  th game
# Playing  832  th game
# Playing  833  th game
# Playing  834  th game
# Playing  835  th game
# Playing  836  th game
# Playing  837  th game
# Playing  838  th game
# Playing  839  th game
# Playing  840  th game
# Playing  841  th game
# Playing  842  th game
# Playing  843  th game
# Playing  844  th game
# Playing  845  th game
# Playing  846  th game
# Playing  847  th game
# Playing  848  th game
# Playing  849  th game
# Playing  850  th game
# Playing  851  th game
# Playing  852  th game
# Playing  853  th game
# Playing  854  th game
# Playing  855  th game
# Playing  856  th game
# Playing  857  th game
# Playing  858  th game
# Playing  859  th game
# Playing  860  th game
# Playing  861  th game
# Playing  862  th game
# Playing  863  th game
# Playing  864  th game
# Playing  865  th game
# Playing  866  th game
# Playing  867  th game
# Playing  868  th game
# Playing  869  th game
# Playing  870  th game
# Playing  871  th game
# Playing  872  th game
# Playing  873  th game
# Playing  874  th game
# Playing  875  th game
# Playing  876  th game
# Playing  877  th game
# Playing  878  th game
# Playing  879  th game
# Playing  880  th game
# Playing  881  th game
# Playing  882  th game
# Playing  883  th game
# Playing  884  th game
# Playing  885  th game
# Playing  886  th game
# Playing  887  th game
# Playing  888  th game
# Playing  889  th game
# Playing  890  th game
# Playing  891  th game
# Playing  892  th game
# Playing  893  th game
# Playing  894  th game
# Playing  895  th game
# Playing  896  th game
# Playing  897  th game
# Playing  898  th game
# Playing  899  th game
# Playing  900  th game
# Playing  901  th game
# Playing  902  th game
# Playing  903  th game
# Playing  904  th game
# Playing  905  th game
# Playing  906  th game
# Playing  907  th game
# Playing  908  th game
# Playing  909  th game
# Playing  910  th game
# Playing  911  th game
# Playing  912  th game
# Playing  913  th game
# Playing  914  th game
# Playing  915  th game
# Playing  916  th game
# Playing  917  th game
# Playing  918  th game
# Playing  919  th game
# Playing  920  th game
# Playing  921  th game
# Playing  922  th game
# Playing  923  th game
# Playing  924  th game
# Playing  925  th game
# Playing  926  th game
# Playing  927  th game
# Playing  928  th game
# Playing  929  th game
# Playing  930  th game
# Playing  931  th game
# Playing  932  th game
# Playing  933  th game
# Playing  934  th game
# Playing  935  th game
# Playing  936  th game
# Playing  937  th game
# Playing  938  th game
# Playing  939  th game
# Playing  940  th game
# Playing  941  th game
# Playing  942  th game
# Playing  943  th game
# Playing  944  th game
# Playing  945  th game
# Playing  946  th game
# Playing  947  th game
# Playing  948  th game
# Playing  949  th game
# Playing  950  th game
# Playing  951  th game
# Playing  952  th game
# Playing  953  th game
# Playing  954  th game
# Playing  955  th game
# Playing  956  th game
# Playing  957  th game
# Playing  958  th game
# Playing  959  th game
# Playing  960  th game
# Playing  961  th game
# Playing  962  th game
# Playing  963  th game
# Playing  964  th game
# Playing  965  th game
# Playing  966  th game
# Playing  967  th game
# Playing  968  th game
# Playing  969  th game
# Playing  970  th game
# Playing  971  th game
# Playing  972  th game
# Playing  973  th game
# Playing  974  th game
# Playing  975  th game
# Playing  976  th game
# Playing  977  th game
# Playing  978  th game
# Playing  979  th game
# Playing  980  th game
# Playing  981  th game
# Playing  982  th game
# Playing  983  th game
# Playing  984  th game
# Playing  985  th game
# Playing  986  th game
# Playing  987  th game
# Playing  988  th game
# Playing  989  th game
# Playing  990  th game
# Playing  991  th game
# Playing  992  th game
# Playing  993  th game
# Playing  994  th game
# Playing  995  th game
# Playing  996  th game
# Playing  997  th game
# Playing  998  th game
# Playing  999  th game
# ---------------------------------------------------------------------------
# HangmanAPIError                           Traceback (most recent call last)
# Cell In[6], line 4
#       2 print('Playing ', i, ' th game')
#       3 # Uncomment the following line to execute your final runs. Do not do this until you are satisfied with your submission
# ----> 4 api.start_game(practice=0,verbose=False)
#       6 # DO NOT REMOVE as otherwise the server may lock you out for too high frequency of requests
#       7 time.sleep(0.5)
#
# Cell In[2], line 115, in HangmanAPI.start_game(self, practice, verbose)
#     112 self.guessed_letters = []
#     113 self.current_dictionary = self.full_dictionary
# --> 115 response = self.request("/new_game", {"practice":practice})
#     116 if response.get('status')=="approved":
#     117     game_id = response.get('game_id')
#
# Cell In[2], line 217, in HangmanAPI.request(self, path, args, post_args, method)
#     214     raise HangmanAPIError('Maintype was not text, or querystring')
#     216 if result and isinstance(result, dict) and result.get("error"):
# --> 217     raise HangmanAPIError(result)
#     218 return result
#
# HangmanAPIError: {'error': 'You have reached 1000 of games', 'status': 'denied'}

# %% [markdown]
# ## To check your game statistics
# 1. Simply use "my_status" method.
# 2. Returns your total number of games, and number of wins.

# %%
[total_practice_runs,total_recorded_runs,total_recorded_successes,total_practice_successes] = api.my_status() # Get my game stats: (# of tries, # of wins)
success_rate = total_recorded_successes/total_recorded_runs
print('overall success rate = %.3f' % success_rate)
# Out:
# overall success rate = 0.275
